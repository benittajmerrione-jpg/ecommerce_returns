# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ecommerce_returns.csv")

# %%
df.head()
# Out:
#    customer_id  product_id basket_date  basket_count  return_rate_percentage
# 0     42366585    41475073   6/19/2019             2                   11.16
# 1     35956841    43279538   6/19/2019             2                    6.90
# 2     26139578    31715598   6/19/2019             3                   16.65
# 3      3262253    47880260   6/19/2019             2                    4.85
# 4     20056678    44747002   6/19/2019             2                   13.94

# %%
df.shape
# Out:
# (499, 5)

# %%
df.columns
# Out:
# Index(['customer_id', 'product_id', 'basket_date', 'basket_count',
#        'return_rate_percentage'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             499 non-null    int64
#  1   product_id              499 non-null    int64
#  2   basket_date             499 non-null    object
#  3   basket_count            499 non-null    int64
#  4   return_rate_percentage  499 non-null    float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 19.6+ KB

# %%
df.isnull().sum()
# Out:
# customer_id               0
# product_id                0
# basket_date               0
# basket_count              0
# return_rate_percentage    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 499

# %%
print(df.columns)
# Out:
# Index(['customer_id', 'product_id', 'basket_date', 'basket_count',
#        'return_rate_percentage'],
#       dtype='object')

# %%
(df["return_rate_percentage"] > 0.5).sum()
# Out:
# np.int64(497)

# %%
((df["return_rate_percentage"] > 0.5).mean()) * 100
# Out:
# np.float64(99.59919839679358)

# %%
df.mean(numeric_only=True)
# Out:
# customer_id               1.910903e+07
# product_id                3.575387e+07
# basket_count              2.130261e+00
# return_rate_percentage    9.093166e+00
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# customer_id               16048941.00
# product_id                39543957.00
# basket_count                     2.00
# return_rate_percentage           7.84
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# customer_id               1.299724e+07
# product_id                1.508244e+07
# basket_count              4.263723e-01
# return_rate_percentage    5.640421e+00
# dtype: float64

# %%
df.describe()
# Out:
#         customer_id    product_id  basket_count  return_rate_percentage
# count  4.990000e+02  4.990000e+02    499.000000              499.000000
# mean   1.910903e+07  3.575387e+07      2.130261                9.093166
# std    1.299724e+07  1.508244e+07      0.426372                5.640421
# min    1.227200e+04  7.582700e+04      2.000000                0.360000
# 25%    8.845304e+06  3.237712e+07      2.000000                4.775000
# 50%    1.604894e+07  3.954396e+07      2.000000                7.840000
# 75%    2.962302e+07  4.668418e+07      2.000000               12.240000
# max    4.441756e+07  5.544566e+07      6.000000               35.230000

# %%
print(df.columns.tolist())
# Out:
# ['customer_id', 'product_id', 'basket_date', 'basket_count', 'return_rate_percentage']

# %%
plt.hist(df["return_rate_percentage"], bins=10)
plt.title("Return Rate Distribution")
plt.xlabel("Return Rate Percentage")
plt.ylabel("Count")
plt.show()

# %%
plt.boxplot(df["return_rate_percentage"])
plt.title("Return Rate Boxplot")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
